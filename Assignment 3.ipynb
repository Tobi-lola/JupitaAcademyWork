# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.

# %%
x=[1, 2, 3, 4, 5]
y=[10, 12, 8, 15, 7]
plt.plot (x,y);
plt.title('Line Plot');

# %% [markdown]
# ## 2.

# %%
a=['A', 'B', 'C', 'D']
b=[25, 40, 15, 30]
plt.xlabel('Categories')
plt.ylabel('Values')
sns.barplot(x=['A', 'B', 'C', 'D'],y=[25, 40, 15, 30], palette='viridis' );
plt.title('Barplot');

# %% [markdown]
# ## 3.

# %%
Data=[32, 45, 50, 28, 36, 42, 38, 25, 29, 52, 48, 60]
sns.histplot(x=Data, bins=25,);
plt.title('Histogram');

# %% [markdown]
# ## 4.

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=[3, 5, 7, 10, 12, 15], y= [25, 40, 30, 50, 35, 60], color='red', alpha=1);
plt.title('Scatterplot')
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %% [markdown]
# ## 5.

# %%
labels=['Apples', 'Bananas', 'Oranges', 'Grapes']
size= [30, 25, 20, 15]
colors=['yellow','blue','black','purple']
plt.pie(size, labels=labels, colors=colors);
plt.axis('equal')
plt.title('Pie Chart')
autopct='%1.1f%%'

# %% [markdown]
# ## 6.

# %%
plt.boxplot(x=[45, 60, 75,300, 80,350, 90, 95, 100, 110, 120,250,200],);

# %% [markdown]
# ## 7.

# %%
x=['A','B','C','D']
y=[25,40,15,30]
plt.barh(x,y);
